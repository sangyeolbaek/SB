# %% [markdown]
# # Image Model Interpretation

# %%
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.applications.resnet50 import preprocess_input, ResNet50
import keras.models
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions

# %% [markdown]
# Some necessary functions for this.

# %%
def get_batch_preds(dataset, model, i):
    batch = dataset[i]
    batch_imgs = batch[0]
    batch_labels = batch[1]
    batch_preds = model.predict(batch_imgs)
    
    return batch_labels, batch_preds

# %%
# display batch for evaluation
# since each batch has 32 items, we will display 16 for visual purposes
def plot_batch(pred_arr, true_arr, img):

    plt.figure(figsize=(16,16))
    
    for i in range(16):
        x = i % 4
        y = i // 4
        
        plt.subplot(4, 4, i+1)
        plt.grid(False)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(img[i*2])
        
        pred_label = np.argmax(pred_arr[i*2])
        if pred_label == np.argmax(true_arr[i*2]):
            color = 'green'
        else:
            color = 'red'
        
        plt.xlabel('Pred: {} {:2.0f}%\nTrue: {}'.format(label_names[pred_label],
                                                             100*np.max(pred_arr[i*2]),
                                                             label_names[np.argmax(true_arr[i*2])]),
                         color=color)
    plt.show()

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=IMAGE_SIZE)
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %% [markdown]
# ## Interpreting 'my_model'

# %%
# load model from 'my_model'
model = keras.models.load_model('my_model')

# %%
IMAGE_SIZE = (160, 160)
BATCH_SIZE = 32
NUM_CLASSES = 4

data_gen = image.ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split = 0.2,
    #rescale=1./255.
)

train_ds = data_gen.flow_from_directory(
    'dataset',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    subset='training',
    seed=420
)

val_ds = data_gen.flow_from_directory(
    'dataset',
    target_size=IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    subset='validation',
    seed=420
)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# <tensorflow.python.keras.preprocessing.image.DirectoryIterator object at 0x64a785850> <tensorflow.python.keras.preprocessing.image.DirectoryIterator object at 0x645f41e50>

# %%
# true labels, predicted labels
first_labels, first_preds = get_batch_preds(val_ds, model, 0)

# %%
# labels are in integers, so I used val_ds.filepaths to determine the label names
label_names = ['cheetah', 'jaguar', 'leopard', 'snow leopard']
label_names
# Out:
# ['cheetah', 'jaguar', 'leopard', 'snow leopard']

# %%
plot_batch(first_preds, first_labels, val_ds[0][0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Reference:
# https://github.com/marcotcr/lime/blob/master/doc/notebooks/Tutorial%20-%20Image%20Classification%20Keras.ipynb

# %%
# list the filepaths associated with the images above
img_paths = np.array(val_ds.filenames)[val_ds.index_array[:BATCH_SIZE:2]]
img_paths
# Out:
# array(['jaguar/jaguar_121.jpg', 'leopard/leopard_114.jpg',
#        'cheetah/cheetah_138.jpg', 'snow leopard/b0xccf.jpg',
#        'cheetah/cheetah_161.jpg', 'cheetah/cheetah_194.jpg',
#        'cheetah/cheetah_171.jpg', 'cheetah/bnym6x.jpg',
#        'cheetah/bbkdy7.jpg', 'snow leopard/2b6dey5.jpg',
#        'cheetah/b60x20.jpg', 'jaguar/jaguar_152.jpg',
#        'jaguar/jaguar_166.jpg', 'cheetah/2bkj609.jpg',
#        'leopard/2b1ejbd.jpg', 'cheetah/cheetah_175.jpg'], dtype='<U33')

# %%
imgs = transform_img_fn([os.path.join('dataset', img_path) for img_path in img_paths])
imgs
# Out:
# array([[[[-5.7939003e+01, -1.9778999e+01, -1.6680000e+01],
#          [-7.9390030e+00,  3.7221001e+01,  3.6320000e+01],
#          [-7.3939003e+01, -2.2778999e+01, -2.5680000e+01],
#          ...,
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.3006100e+02,  1.0022100e+02,  7.2320000e+01]],
#
#         [[-2.9939003e+01, -1.7789993e+00,  6.3199997e+00],
#          [-4.5939003e+01, -1.0778999e+01, -5.6800003e+00],
#          [-5.4939003e+01, -1.3778999e+01, -9.6800003e+00],
#          ...,
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.3006100e+02,  1.0022100e+02,  7.2320000e+01]],
#
#         [[-1.6939003e+01,  7.2210007e+00,  2.2320000e+01],
#          [-5.6939003e+01, -2.6778999e+01, -1.4680000e+01],
#          [-4.0939003e+01, -5.7789993e+00,  5.3199997e+00],
#          ...,
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.2706100e+02,  9.9221001e+01,  7.3320000e+01],
#          [ 1.3006100e+02,  1.0022100e+02,  7.2320000e+01]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]],
#
#
#        [[[ 6.0609970e+00, -1.0778999e+01, -1.2680000e+01],
#          [-4.9390030e+00, -1.5778999e+01, -2.1680000e+01],
#          [-5.1939003e+01, -5.1778999e+01, -4.4680000e+01],
#          ...,
#          [ 1.5060997e+01,  1.6221001e+01,  8.3199997e+00],
#          [-3.9390030e+00, -1.0778999e+01, -1.0680000e+01],
#          [ 3.8060997e+01,  3.6221001e+01,  2.7320000e+01]],
#
#         [[-4.9390030e+00, -1.8778999e+01, -2.1680000e+01],
#          [-4.0939003e+01, -5.4778999e+01, -5.9680000e+01],
#          [-4.4939003e+01, -4.8778999e+01, -4.1680000e+01],
#          ...,
#          [ 3.9060997e+01,  4.3221001e+01,  2.3320000e+01],
#          [ 2.0060997e+01,  1.9221001e+01,  6.3199997e+00],
#          [-3.4939003e+01, -1.4778999e+01, -1.2680000e+01]],
#
#         [[-1.9390030e+00, -1.1778999e+01, -1.4680000e+01],
#          [-1.1939003e+01, -2.5778999e+01, -3.0680000e+01],
#          [-2.9939003e+01, -3.7778999e+01, -2.9680000e+01],
#          ...,
#          [ 2.0609970e+00,  1.2221001e+01, -9.6800003e+00],
#          [ 3.3060997e+01,  4.4221001e+01,  2.7320000e+01],
#          [ 1.1060997e+01,  1.7221001e+01, -4.6800003e+00]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]],
#
#
#        [[[ 1.7060997e+01,  4.4221001e+01,  6.5320000e+01],
#          [ 7.0609970e+00,  3.1221001e+01,  5.2320000e+01],
#          [-4.9390030e+00,  1.6221001e+01,  3.8320000e+01],
#          ...,
#          [ 8.1060997e+01,  6.2221001e+01,  5.0320000e+01],
#          [ 1.0606100e+02,  8.7221001e+01,  7.5320000e+01],
#          [ 1.1506100e+02,  9.9221001e+01,  8.8320000e+01]],
#
#         [[ 2.1060997e+01,  4.9221001e+01,  6.7320000e+01],
#          [ 4.0609970e+00,  2.8221001e+01,  4.7320000e+01],
#          [ 4.0609970e+00,  2.6221001e+01,  4.5320000e+01],
#          ...,
#          [ 8.2060997e+01,  6.5221001e+01,  5.7320000e+01],
#          [ 9.9060997e+01,  8.2221001e+01,  7.4320000e+01],
#          [ 1.0806100e+02,  9.3221001e+01,  8.5320000e+01]],
#
#         [[ 1.7060997e+01,  4.6221001e+01,  6.2320000e+01],
#          [ 2.8060997e+01,  5.3221001e+01,  7.0320000e+01],
#          [ 6.0997009e-02,  2.3221001e+01,  4.0320000e+01],
#          ...,
#          [ 7.9060997e+01,  6.8221001e+01,  6.2320000e+01],
#          [ 9.0060997e+01,  7.9221001e+01,  7.3320000e+01],
#          [ 1.0106100e+02,  8.8221001e+01,  8.1320000e+01]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]],
#
#
#        ...,
#
#
#        [[[ 2.8060997e+01,  2.5221001e+01,  3.5320000e+01],
#          [ 3.5060997e+01,  3.2221001e+01,  4.2320000e+01],
#          [ 3.0060997e+01,  3.0221001e+01,  3.9320000e+01],
#          ...,
#          [-6.5939003e+01, -6.9778999e+01, -7.3680000e+01],
#          [-5.5939003e+01, -5.9778999e+01, -6.3680000e+01],
#          [-6.5939003e+01, -6.9778999e+01, -7.2680000e+01]],
#
#         [[ 2.5060997e+01,  2.3221001e+01,  3.0320000e+01],
#          [ 3.2060997e+01,  3.0221001e+01,  3.7320000e+01],
#          [ 2.7060997e+01,  2.7221001e+01,  3.4320000e+01],
#          ...,
#          [-7.3939003e+01, -7.7778999e+01, -8.0680000e+01],
#          [-5.7939003e+01, -6.1778999e+01, -6.4680000e+01],
#          [-7.4939003e+01, -7.9778999e+01, -7.9680000e+01]],
#
#         [[ 1.9060997e+01,  1.8221001e+01,  2.3320000e+01],
#          [ 2.5060997e+01,  2.4221001e+01,  2.9320000e+01],
#          [ 2.1060997e+01,  2.2221001e+01,  2.7320000e+01],
#          ...,
#          [-8.0939003e+01, -8.8778999e+01, -8.6680000e+01],
#          [-6.6939003e+01, -7.4778999e+01, -7.2680000e+01],
#          [-7.2939003e+01, -8.0778999e+01, -7.8680000e+01]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]],
#
#
#        [[[-2.2939003e+01,  2.5221001e+01, -1.6800003e+00],
#          [-1.5939003e+01,  2.3221001e+01,  6.3199997e+00],
#          [-2.5939003e+01,  1.5221001e+01,  1.3199997e+00],
#          ...,
#          [-3.7939003e+01,  2.8221001e+01, -2.1680000e+01],
#          [-3.7939003e+01,  1.4221001e+01, -3.1680000e+01],
#          [-3.7939003e+01, -3.7789993e+00, -3.6680000e+01]],
#
#         [[-1.9390030e+00,  3.8221001e+01,  1.1320000e+01],
#          [-1.3939003e+01,  1.6221001e+01, -1.6800003e+00],
#          [-2.3939003e+01,  1.4221001e+01, -6.8000031e-01],
#          ...,
#          [-3.2939003e+01,  2.9221001e+01, -2.1680000e+01],
#          [-3.0939003e+01,  2.0221001e+01, -2.8680000e+01],
#          [-3.3939003e+01, -7.7899933e-01, -3.6680000e+01]],
#
#         [[ 2.3060997e+01,  5.1221001e+01,  2.3320000e+01],
#          [ 4.0609970e+00,  2.7221001e+01,  8.3199997e+00],
#          [-2.2939003e+01,  9.2210007e+00, -6.6800003e+00],
#          ...,
#          [-2.4939003e+01,  2.8221001e+01, -1.9680000e+01],
#          [-2.6939003e+01,  2.1221001e+01, -2.9680000e+01],
#          [-2.6939003e+01,  4.2210007e+00, -3.3680000e+01]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]],
#
#
#        [[[ 6.0997009e-02,  2.7221001e+01,  3.8320000e+01],
#          [ 1.3060997e+01,  5.2221001e+01,  5.8320000e+01],
#          [ 2.1060997e+01,  5.0221001e+01,  6.6320000e+01],
#          ...,
#          [-3.7939003e+01,  1.3221001e+01,  1.3199997e+00],
#          [-2.7939003e+01,  9.2210007e+00,  2.5320000e+01],
#          [-3.9390030e+00,  2.6221001e+01,  4.0320000e+01]],
#
#         [[ 1.1060997e+01,  3.2221001e+01,  4.9320000e+01],
#          [-6.9390030e+00,  3.2221001e+01,  4.1320000e+01],
#          [ 2.2060997e+01,  6.3221001e+01,  6.7320000e+01],
#          ...,
#          [-2.1939003e+01,  2.0221001e+01,  2.0320000e+01],
#          [-2.0939003e+01,  1.2221001e+01,  2.9320000e+01],
#          [-5.9390030e+00,  2.6221001e+01,  4.0320000e+01]],
#
#         [[ 5.0609970e+00,  2.9221001e+01,  4.4320000e+01],
#          [-2.0939003e+01,  2.1221001e+01,  2.7320000e+01],
#          [ 2.1060997e+01,  6.5221001e+01,  6.0320000e+01],
#          ...,
#          [-7.9390030e+00,  2.6221001e+01,  4.0320000e+01],
#          [-1.9390030e+00,  2.5221001e+01,  4.6320000e+01],
#          [ 2.3060997e+01,  6.0221001e+01,  6.5320000e+01]],
#
#         ...,
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]],
#
#         [[ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          ...,
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02],
#          [ 1.5106100e+02,  1.3822101e+02,  1.3132001e+02]]]],
#       dtype=float32)

# %% [markdown]
# ### Explanation time
#
# Let's explain the models' prediction for the first listed image.

# %%
# %load_ext autoreload
# %autoreload 2
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image

# %%
from skimage.segmentation import mark_boundaries

# %% [markdown]
# Let's use the first image on the batch as an example.

# %%
# function that renders preprocessed image to its original colors
orig_color = lambda img: img[:,:, [2,1,0]] / 255. + 0.5

# %%
# mark boundaries around image to show why the model predicted that way
def show_model_interpretation(img, model, top_label_i=0):
    explainer = lime_image.LimeImageExplainer()
    explanation = explainer.explain_instance(img.astype('double'), model.predict,
                                             top_labels=2, hide_color=0, num_samples=800)
    
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[top_label_i], positive_only=True,
                                                num_features=4, hide_rest=False)
    plt.imshow(mark_boundaries(orig_color(temp), mask))

# %%
show_model_interpretation(imgs[0], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Let's look some images that were "100% predicted correctly" or close to it.
#
# Following images belong to in this order:
# 1. cheetah
# 2. snow leopard
# 3. jaguar
#
# For leopard, the image shown above in which the model predicted scored 72% at the highest, so we will omit it.

# %%
# cheetah
show_model_interpretation(imgs[4], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# snow leopard
show_model_interpretation(imgs[3], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# jaguar
show_model_interpretation(imgs[12], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# In this batch, two images were wrongly predicted. It would be the 11th and 15th images shown, at indices 20 and 28 in the batch, respective.

# %%
# 
(first_preds[[20,28]] * 100).astype(int)
# Out:
# array([[ 8,  0, 91,  0],
#        [ 0, 56, 43,  0]])

# %% [markdown]
# Looks like for both mispredictions, the correct one is the second predictions.

# %%
show_model_interpretation(imgs[10], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show_model_interpretationel_interpretationodel_interpretation(imgs[10], model, 1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show_model_interpretation(imgs[14], model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show_model_interpretation(imgs[14], model, 1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Interpreting 'my_model_2'

# %% [markdown]
# Let's analyze the model's predictions from the model generated by `my_model_2`

# %%
model_2 = keras.models.load_model('my_model_2')

# %%
# I will use the same batch of images, but with higher resolution
IMAGE_SIZE = (200, 200)
BATCH_SIZE = 32
NUM_CLASSES = 4

data_gen_2 = image.ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split = 0.2,
)

train_ds_2 = data_gen.flow_from_directory(
    'dataset',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    subset='training',
    seed=420
)

val_ds_2 = data_gen.flow_from_directory(
    'dataset',
    target_size=IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    subset='validation',
    seed=420
)
   
#print(train_ds, val_ds)
# Out:
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
first_labels_2, first_preds_2 = get_batch_preds(val_ds_2, model_2, 0)

# %%
plot_batch(first_preds_2, first_labels_2, val_ds_2[0][0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# it will use the new IMAGE_SIZE = (200, 200)
imgs_2 = transform_img_fn([os.path.join('dataset', img_path) for img_path in img_paths])

# %%
show_model_interpretation(imgs_2[0], model_2)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=800.0), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# work on this later...

# %%
show_model_interpretation(imgs_2[0], model_2)
