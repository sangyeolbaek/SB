# %%
# Run data cleaner (takes a while)
# %run './data_wrangling_capstone_1.ipynb'

# %%
phone_df.tail()
# Out:
#               Issue Occurred   Form  \
# 1756450  2020-04-08 16:00:00  Phone
# 1756451  2020-04-08 03:36:30  Phone
# 1756452  2020-04-08 16:11:00  Phone
# 1756453  2020-04-09 03:40:33  Phone
# 1756456  2020-04-09 03:53:49  Phone
#
#                                             Method  \
# 1756450  Wireless (cell phone/other mobile device)
# 1756451                                      Wired
# 1756452  Wireless (cell phone/other mobile device)
# 1756453  Wireless (cell phone/other mobile device)
# 1756456  Wireless (cell phone/other mobile device)
#
#                                                   Issue             City  \
# 1756450                                  Unwanted Calls    Mountain View
# 1756451                                  Unwanted Calls  Prescott Valley
# 1756452                                  Unwanted Calls       Plantation
# 1756453                                       Equipment    Miami Gardens
# 1756456  Availability (including rural call completion)   Farmers Branch
#
#         State    Zip
# 1756450    HI  96771
# 1756451    AZ  86314
# 1756452    FL  33317
# 1756453    FL  33054
# 1756456    TX  75234

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Where do robocalls occur most frequently in the US?
phone_df['State'].value_counts(ascending=True).tail(10).plot(kind='barh', figsize=(16, 9), title='Top 10 US States for Robocalls', fontsize=15)

# %%
# What times of the day are robocalls most frequent?
time_s = phone_df['Issue Occurred'].apply(lambda t: t.second + 60*(t.minute + 60*t.hour))
x = [i * 3600 for i in range(24)]
x_label = [(str(i%12) if i%12 != 0 else '12') + ('AM' if i < 12 else 'PM') for i in range(24)]

# plot time frequency
ax = time_s.plot(kind='hist', title='Robocalls during the day', bins=24, range=(0,24*60*60), figsize=(15,6), xticks=x)
ax.set_xticklabels(x_label)
# Out:
# [Text(0, 0, '12AM'),
#  Text(0, 0, '1AM'),
#  Text(0, 0, '2AM'),
#  Text(0, 0, '3AM'),
#  Text(0, 0, '4AM'),
#  Text(0, 0, '5AM'),
#  Text(0, 0, '6AM'),
#  Text(0, 0, '7AM'),
#  Text(0, 0, '8AM'),
#  Text(0, 0, '9AM'),
#  Text(0, 0, '10AM'),
#  Text(0, 0, '11AM'),
#  Text(0, 0, '12PM'),
#  Text(0, 0, '1PM'),
#  Text(0, 0, '2PM'),
#  Text(0, 0, '3PM'),
#  Text(0, 0, '4PM'),
#  Text(0, 0, '5PM'),
#  Text(0, 0, '6PM'),
#  Text(0, 0, '7PM'),
#  Text(0, 0, '8PM'),
#  Text(0, 0, '9PM'),
#  Text(0, 0, '10PM'),
#  Text(0, 0, '11PM')]

# %%
# Most common methods and issues?
fig, axes = plt.subplots(nrows=2, ncols=1)

phone_df['Method'].value_counts().plot(ax=axes[0], kind='pie', figsize=(15,15), legend=True)
phone_df['Issue'].value_counts().plot(ax=axes[1], kind='pie', figsize=(15,15))
